# %% [markdown]
# ## NLP Topic Modeling Exercise

# %%
# import TfidfVectorizer and CountVectorizer from sklearn
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# import fetch_20newsgroups from sklearn.datasets
from sklearn.datasets import fetch_20newsgroups

# import NMF and LatentDirichletAllocation from sklearn
from sklearn.decomposition import NMF, LatentDirichletAllocation

# %%
dataset = fetch_20newsgroups(shuffle=True, random_state=1, remove=('headers', 'footers', 'quotes'))
documents = dataset.data

# %% [markdown]
# * create a variable called `'no_features'` and set its value to 100.

# %%
no_features = 100

# %% [markdown]
# * create a variable `'no_topics'` and set its value to 100

# %%
no_topics = 100

# %% [markdown]
# ## NMF

# %% [markdown]
# * instantiate a TfidfVectorizer with the following parameters:
#
#
#     * max_df = 0.95
#     * min_df = 2
#     * max_features = no_features
#     * stop_words = 'english'

# %%
vec = TfidfVectorizer(max_df = 0.95, min_df = 2, max_features = no_features, stop_words = 'english')

# %% [markdown]
# * use fit_transform method of TfidfVectorizer to transform the documents

# %%
X = vec.fit_transform(documents)

# %% [markdown]
# * get the features names from TfidfVectorizer

# %%
print(vec.get_feature_names())
# Out:
# ['00', '10', '12', '14', '15', '16', '20', '25', 'a86', 'available', 'ax', 'b8f', 'believe', 'best', 'better', 'bit', 'case', 'com', 'come', 'course', 'data', 'day', 'did', 'didn', 'different', 'does', 'doesn', 'don', 'drive', 'edu', 'fact', 'far', 'file', 'g9v', 'god', 'going', 'good', 'got', 'government', 'help', 'information', 'jesus', 'just', 'key', 'know', 'law', 'let', 'like', 'line', 'list', 'little', 'll', 'long', 'look', 'lot', 'mail', 'make', 'max', 'mr', 'need', 'new', 'number', 'people', 'point', 'power', 'probably', 'problem', 'program', 'question', 'read', 'really', 'right', 'run', 'said', 'say', 'second', 'set', 'software', 'space', 'state', 'sure', 'tell', 'thanks', 'thing', 'things', 'think', 'time', 'true', 'try', 'use', 'used', 'using', 've', 'want', 'way', 'windows', 'work', 'world', 'year', 'years']

# %% [markdown]
# * instantiate NMF and fit transformed data

# %%
nmf = NMF()
nmf_fitted = nmf.fit_transform(X)
# Out:
# F:\Anaconda\envs\lhl\lib\site-packages\sklearn\decomposition\_nmf.py:315: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   "'nndsvda' in 1.1 (renaming of 0.26)."), FutureWarning)

# %%
print(nmf_fitted.shape)  # (NO_DOCUMENTS, NO_TOPICS)
# Out:
# (11314, 100)

# %% [markdown]
# ## LDA w/ Sklearn

# %% [markdown]
# * instantiate a CountVectorizer with following parameters:
#
#
#     * max_df = 0.95
#     * min_df = 2
#     * max_features = no_features
#     * stop_words = 'english'

# %%
count_vec = CountVectorizer(max_df = 0.95, min_df = 2, max_features = no_features, stop_words = 'english')

# %% [markdown]
# * use fit_transform method of CountVectorizer to transform documents

# %%
X2 = count_vec.fit_transform(documents)

# %% [markdown]
# * get the features names from TfidfVectorizer

# %%
print(count_vec.get_feature_names())
# Out:
# ['00', '10', '12', '14', '15', '16', '20', '25', 'a86', 'available', 'ax', 'b8f', 'believe', 'best', 'better', 'bit', 'case', 'com', 'come', 'course', 'data', 'day', 'did', 'didn', 'different', 'does', 'doesn', 'don', 'drive', 'edu', 'fact', 'far', 'file', 'g9v', 'god', 'going', 'good', 'got', 'government', 'help', 'information', 'jesus', 'just', 'key', 'know', 'law', 'let', 'like', 'line', 'list', 'little', 'll', 'long', 'look', 'lot', 'mail', 'make', 'max', 'mr', 'need', 'new', 'number', 'people', 'point', 'power', 'probably', 'problem', 'program', 'question', 'read', 'really', 'right', 'run', 'said', 'say', 'second', 'set', 'software', 'space', 'state', 'sure', 'tell', 'thanks', 'thing', 'things', 'think', 'time', 'true', 'try', 'use', 'used', 'using', 've', 'want', 'way', 'windows', 'work', 'world', 'year', 'years']

# %% [markdown]
# * instantiate LatentDirichletAllocation and fit transformed data

# %%
lda = LatentDirichletAllocation()
lda_fitted = lda.fit_transform(X2)

# %% [markdown]
# * create a function `display_topics` that is able to display the top words in a topic for different models

# %%
def print_topics(model, vectorizer, top_n=10):
    for idx, topic in enumerate(model.components_):
        print("Topic %d:" % (idx))
        print([(vectorizer.get_feature_names()[i], topic[i])
                        for i in topic.argsort()[:-top_n - 1:-1]])
#         if idx == 9:
#             break

# %% [markdown]
# * display top 10 words from each topic from NMF model

# %%
print("NMF Model:")
print_topics(nmf, vec)
# Out:
# NMF Model:
# Topic 0:
# [('did', 16.40089167562295), ('just', 2.7125032748952746e-07), ('ll', 6.068010410205508e-09), ('data', 3.4930937935321226e-10), ('years', 0.0), ('going', 0.0), ('don', 0.0), ('drive', 0.0), ('edu', 0.0), ('fact', 0.0)]
# Topic 1:
# [('thanks', 10.587911306174842), ('14', 6.19577186560542e-06), ('file', 1.261614559601937e-07), ('data', 3.2150618082632774e-10), ('years', 0.0), ('going', 0.0), ('don', 0.0), ('drive', 0.0), ('edu', 0.0), ('fact', 0.0)]
# Topic 2:
# [('does', 4.436783869191332), ('know', 8.159441789334389e-05), ('just', 2.3191431546221394e-07), ('ll', 4.134329650471942e-09), ('data', 2.8295448876162086e-10), ('years', 0.0), ('god', 0.0), ('don', 0.0), ('drive', 0.0), ('edu', 0.0)]
# Topic 3:
# [('edu', 5.083671527080077), ('14', 1.5876118805757653e-06), ('file', 1.0610127259158247e-06), ('just', 8.851142897319139e-08), ('ll', 5.013211101913869e-09), ('data', 2.0520599540926969e-10), ('line', 1.907036395945729e-12), ('going', 0.0), ('don', 0.0), ('drive', 0.0)]
# Topic 4:
# [('just', 3.0201225902346263), ('don', 0.005013019463165245), ('like', 8.886391445557676e-06), ('tell', 2.010047701579831e-06), ('ll', 5.6199917316785985e-08), ('ve', 1.1499504560597671e-08), ('years', 0.0), ('god', 0.0), ('doesn', 0.0), ('drive', 0.0)]
# Topic 5:
# [('like', 4.679417075001166), ('14', 6.343481011714326e-07), ('just', 7.266780850371554e-08), ('file', 2.2507312257018755e-08), ('data', 7.059871965834089e-11), ('years', 0.0), ('going', 0.0), ('don', 0.0), ('drive', 0.0), ('edu', 0.0)]
# Topic 6:
# [('just', 4.549772041557074), ('a86', 0.0023202350827540297), ('g9v', 0.0006518700330566774), ('does', 1.5180746668549581e-05), ('think', 7.237495664732072e-09), ('doesn', 0.0), ('don', 0.0), ('drive', 0.0), ('edu', 0.0), ('fact', 0.0)]
# Topic 7:
# [('use', 5.257045255531667), ('don', 4.5439145815254887e-05), ('ve', 1.6074743068082845e-09), ('data', 3.9451439953785075e-10), ('years', 0.0), ('going', 0.0), ('doesn', 0.0), ('drive', 0.0), ('edu', 0.0), ('fact', 0.0)]
# Topic 8:
# [('people', 6.230080946432315), ('don', 0.0001219159632946525), ('just', 9.231269719890832e-08), ('mr', 8.209533450824934e-08), ('ll', 9.59995399650011e-09), ('ve', 1.6285213249250869e-09), ('years', 0.0), ('going', 0.0), ('drive', 0.0), ('edu', 0.0)]
# Topic 9:
# [('good', 6.346541272243195), ('14', 1.1901985028210614e-06), ('ll', 3.410571211390599e-08), ('just', 2.328808957109046e-10), ('data', 3.900840499233551e-11), ('years', 0.0), ('going', 0.0), ('don', 0.0), ('drive', 0.0), ('edu', 0.0)]
# Topic 10:
# [('think', 4.285859024520988), ('don', 0.00017138647897544664), ('years', 0.0), ('going', 0.0), ('doesn', 0.0), ('drive', 0.0), ('edu', 0.0), ('fact', 0.0), ('far', 0.0), ('file', 0.0)]
# Topic 11:
# [('god', 4.6822801106077305), ('don', 0.00011154537818529075), ('tell', 6.770331652050201e-06), ('jesus', 4.685190285443091e-07), ('14', 4.0237063761155954e-07), ('just', 2.870333532351381e-08), ('ll', 2.5956825534396785e-08), ('25', 5.581341845973715e-10), ('years', 0.0), ('going', 0.0)]
# Topic 12:
# [('time', 8.11771450601982), ('just', 8.019578578240293e-07), ('ll', 9.24329060406355e-08), ('ve', 3.667259246043539e-08), ('did', 3.799568872372874e-12), ('want', 4.532767779863656e-13), ('key', 0.0), ('doesn', 0.0), ('don', 0.0), ('drive', 0.0)]
# Topic 13:
# [('windows', 5.351227473129382), ('tell', 6.781207249730136e-07), ('data', 2.3589951268974043e-10), ('years', 0.0), ('going', 0.0), ('doesn', 0.0), ('don', 0.0), ('drive', 0.0), ('edu', 0.0), ('fact', 0.0)]
# Topic 14:
# [('drive', 7.083651867200095), ('problem', 3.386269878447403e-05), ('power', 1.1395447653969505e-06), ('file', 3.070362824265577e-07), ('data', 7.317365542839785e-10), ('years', 0.0), ('does', 0.0), ('don', 0.0), ('edu', 0.0), ('fact', 0.0)]
# Topic 15:
# [('tell', 4.06332792377861), ('ll', 3.930886644746492e-08), ('power', 1.3131150316883597e-08), ('mail', 9.258033427725628e-10), ('program', 4.968886650901264e-10), ('software', 1.743151964236962e-10), ('data', 1.660303382873651e-10), ('doesn', 2.1834685390472677e-11), ('did', 2.6961194861287634e-13), ('years', 0.0)]
# Topic 16:
# [('don', 7.051240061996488), ('ll', 2.686005951705135e-08), ('data', 1.5258132800457803e-10), ('want', 1.6146896130658114e-12), ('did', 2.0228657724336328e-13), ('years', 0.0), ('going', 0.0), ('drive', 0.0), ('edu', 0.0), ('fact', 0.0)]
# Topic 17:
# [('ve', 3.712382840098415), ('b8f', 0.00030084416394437845), ('did', 4.0130312215386816e-14), ('good', 0.0), ('don', 0.0), ('drive', 0.0), ('edu', 0.0), ('fact', 0.0), ('far', 0.0), ('file', 0.0)]
# Topic 18:
# [('bit', 5.274429767131531), ('ax', 0.00010433027839599927), ('just', 4.0847876173641825e-07), ('10', 2.1591817042942407e-07), ('let', 1.801498984722578e-07), ('file', 1.4278411325400745e-07), ('power', 1.677708170489105e-08), ('years', 0.0), ('going', 0.0), ('drive', 0.0)]
# Topic 19:
# [('com', 5.038928535461964), ('file', 5.554458170526451e-07), ('just', 1.25019497574654e-07), ('14', 3.9955490455822674e-09), ('data', 4.5587480673129605e-10), ('set', 1.5194359794914596e-10), ('mail', 1.1512206565384187e-10), ('line', 8.178967699780438e-11), ('want', 3.600807433227778e-13), ('going', 0.0)]
# Topic 20:
# [('need', 4.370648003800445), ('file', 1.0885534669793298e-07), ('ll', 7.038175063002862e-08), ('just', 3.8669554697588534e-08), ('data', 3.3813655225274153e-10), ('mail', 4.982623493704867e-11), ('want', 7.02590884351579e-14), ('going', 0.0), ('don', 0.0), ('drive', 0.0)]
# Topic 21:
# [('used', 6.592515696355968), ('ax', 2.429206024043679e-05), ('just', 4.0425500477600315e-08), ('ve', 1.2577494434593247e-08), ('want', 2.639508816496254e-13), ('did', 4.987753360853327e-14), ('going', 0.0), ('doesn', 0.0), ('don', 0.0), ('drive', 0.0)]
# Topic 22:
# [('year', 7.399127316230768), ('14', 1.876271096874338e-05), ('10', 3.6381510159845975e-07), ('ll', 2.96835130333312e-07), ('just', 2.6642821641633853e-07), ('better', 3.380688003851718e-08), ('ve', 2.6839807051897148e-08), ('did', 2.0598324926717657e-13), ('want', 1.1255158157062542e-13), ('far', 0.0)]
# Topic 23:
# [('right', 4.1035750999050515), ('10', 2.0908630084075426e-07), ('25', 2.2091565324324092e-08), ('did', 2.6967933446156312e-14), ('good', 0.0), ('don', 0.0), ('drive', 0.0), ('edu', 0.0), ('fact', 0.0), ('far', 0.0)]
# Topic 24:
# [('problem', 7.004542882371746), ('file', 7.945786754792209e-07), ('ve', 1.332924730182076e-08), ('want', 6.703568903562127e-13), ('really', 1.2436061192417772e-13), ('did', 1.8885730155410348e-14), ('god', 0.0), ('doesn', 0.0), ('don', 0.0), ('drive', 0.0)]
# Topic 25:
# [('make', 4.317420104393591), ('14', 5.248374392158324e-06), ('just', 8.602977013677136e-08), ('ll', 3.298746024030538e-08), ('data', 3.8590313048619007e-11), ('mail', 7.700574859210464e-12), ('did', 1.2100085772625383e-13), ('years', 0.0), ('going', 0.0), ('drive', 0.0)]
# Topic 26:
# [('mail', 5.213633136123844), ('ax', 7.958996657623435e-05), ('mr', 1.2660394470856872e-06), ('file', 2.070310221279903e-07), ('ll', 6.237538423328549e-08), ('let', 2.598939798095045e-08), ('good', 0.0), ('don', 0.0), ('drive', 0.0), ('edu', 0.0)]
# Topic 27:
# [('way', 5.6229418916340945), ('just', 6.731743093678264e-08), ('ll', 5.972252459670385e-08), ('data', 4.8264803427831975e-11), ('did', 1.537632652107363e-13), ('years', 0.0), ('going', 0.0), ('don', 0.0), ('drive', 0.0), ('edu', 0.0)]
# Topic 28:
# [('want', 6.688989058834369), ('ll', 9.402149466030101e-09), ('data', 7.278472259654907e-10), ('set', 2.739517705957224e-10), ('line', 3.6863519657223274e-11), ('did', 1.2503037669174371e-14), ('going', 0.0), ('don', 0.0), ('drive', 0.0), ('edu', 0.0)]
# Topic 29:
# [('10', 6.59886343797988), ('b8f', 0.0046507554670692786), ('a86', 0.00034605629164842223), ('20', 4.072290186401622e-09), ('did', 5.0773433730976155e-14), ('years', 0.0), ('got', 0.0), ('edu', 0.0), ('fact', 0.0), ('far', 0.0)]
# Topic 30:
# [('want', 3.824190899994736), ('new', 6.595412104117236e-06), ('ll', 2.5594630975075893e-07), ('just', 1.5389334663174965e-07), ('work', 5.199968561855016e-08), ('ve', 2.1769931633773846e-09), ('program', 1.6046383885107583e-10), ('mail', 5.040071344807441e-11), ('really', 4.780455686615757e-13), ('years', 0.0)]
# Topic 31:
# [('really', 5.271789836903085), ('ll', 2.4270375073071668e-08), ('data', 2.7547768933377856e-10), ('did', 5.109117315339035e-14), ('years', 0.0), ('going', 0.0), ('drive', 0.0), ('edu', 0.0), ('fact', 0.0), ('far', 0.0)]
# Topic 32:
# [('said', 4.7498231814992256), ('mr', 1.8752530920554887e-07), ('file', 1.4859599200618603e-07), ('just', 1.0603957777931316e-07), ('ll', 9.303932243247503e-08), ('let', 2.7019566773593524e-08), ('data', 3.0640990138385404e-11), ('doesn', 6.223090380797137e-13), ('did', 2.3571613936151435e-13), ('key', 0.0)]
# Topic 33:
# [('say', 7.926678762516816), ('just', 1.195043039525455e-07), ('ll', 4.672306314563366e-08), ('mr', 2.7251327428288368e-08), ('data', 3.838992126450212e-11), ('doesn', 2.990733193016519e-11), ('did', 3.630209433301201e-13), ('key', 0.0), ('jesus', 0.0), ('don', 0.0)]
# Topic 34:
# [('space', 5.3263815666190695), ('14', 2.0134951560767448e-05), ('file', 8.036280727336978e-07), ('just', 4.490311471240641e-07), ('10', 3.193443586898963e-07), ('ll', 7.079574455719109e-08), ('power', 6.329770676185937e-08), ('25', 1.6690085175539075e-08), ('data', 2.6816588339611803e-10), ('want', 2.008129489806872e-12)]
# Topic 35:
# [('point', 6.592227189639161), ('14', 7.349899652646517e-06), ('10', 9.743271233995613e-08), ('ll', 2.2584827441950347e-08), ('data', 8.263945981905153e-10), ('line', 1.0472561571961012e-10), ('doesn', 1.0239759729682079e-11), ('did', 1.2425358351875922e-13), ('going', 0.0), ('edu', 0.0)]
# Topic 36:
# [('work', 6.599521732461069), ('14', 1.136588571881691e-05), ('file', 4.1361585565405165e-07), ('just', 3.237906761335664e-07), ('ll', 4.812302828409251e-08), ('doesn', 1.1044847041643962e-11), ('want', 6.364355076566458e-13), ('did', 1.5127463993825437e-13), ('going', 0.0), ('don', 0.0)]
# Topic 37:
# [('file', 11.159555221928095), ('a86', 0.02023295713850703), ('g9v', 0.006584224108687638), ('data', 1.229288365188939e-09), ('set', 8.894773207665726e-10), ('line', 5.413565986228727e-10), ('mail', 2.12506843286758e-10), ('program', 8.264497397059726e-11), ('going', 0.0), ('drive', 0.0)]
# Topic 38:
# [('believe', 4.829259565723744), ('file', 8.364517618957893e-08), ('ve', 1.1441533600103552e-08), ('doesn', 7.98555084416044e-12), ('did', 2.4306531922707698e-14), ('don', 0.0), ('drive', 0.0), ('edu', 0.0), ('fact', 0.0), ('far', 0.0)]
# Topic 39:
# [('got', 8.344308751333093), ('just', 6.159299641024808e-07), ('file', 5.780162320833232e-07), ('ll', 1.6036486576839918e-07), ('ve', 5.065919595415871e-08), ('did', 1.0256323188137526e-13), ('going', 0.0), ('don', 0.0), ('drive', 0.0), ('edu', 0.0)]
# Topic 40:
# [('using', 9.215528851441695), ('14', 5.97325497449018e-05), ('file', 1.340046703091108e-06), ('just', 4.956275401304312e-07), ('ve', 5.993332765719089e-08), ('ll', 5.480281127990776e-08), ('really', 4.359723575013281e-15), ('going', 0.0), ('doesn', 0.0), ('don', 0.0)]
# Topic 41:
# [('sure', 5.105171561077889), ('file', 8.353893546824555e-08), ('ll', 2.2231637224003945e-08), ('new', 2.008492206042756e-08), ('data', 7.276562806470975e-11), ('doesn', 4.960655508813676e-12), ('did', 3.9718045924903924e-14), ('god', 0.0), ('don', 0.0), ('drive', 0.0)]
# Topic 42:
# [('question', 5.565236336475077), ('ax', 3.089320883916581e-05), ('mr', 8.154290065583264e-07), ('ll', 2.81649075225495e-08), ('doesn', 5.591515157736993e-12), ('did', 2.3201782983984094e-13), ('years', 0.0), ('going', 0.0), ('drive', 0.0), ('edu', 0.0)]
# Topic 43:
# [('probably', 14.204278033185737), ('ll', 1.355686679640173e-07), ('new', 1.2136559993551131e-08), ('data', 1.1199926968563356e-10), ('doesn', 1.0853507285264603e-11), ('going', 0.0), ('don', 0.0), ('drive', 0.0), ('edu', 0.0), ('fact', 0.0)]
# Topic 44:
# [('ll', 12.403466426881208), ('b8f', 0.006536491512145572), ('g9v', 0.0012380828622436048), ('doesn', 4.2611377969400104e-11), ('did', 1.0124946419503351e-13), ('good', 0.0), ('don', 0.0), ('drive', 0.0), ('edu', 0.0), ('fact', 0.0)]
# Topic 45:
# [('key', 6.726080979714384), ('file', 9.849480281308245e-07), ('new', 9.265229228439277e-08), ('information', 9.014114277263259e-08), ('10', 1.516155297606178e-08), ('going', 9.294559346785579e-09), ('using', 6.574962188877159e-09), ('data', 5.294540289148123e-10), ('program', 4.996909610943142e-11), ('doesn', 5.41171945258683e-12)]
# Topic 46:
# [('going', 7.711120252847131), ('ax', 1.264036283411826e-05), ('ll', 1.6591077478115277e-07), ('better', 9.089671885085117e-08), ('just', 8.183317743307005e-08), ('ve', 7.186124115556684e-08), ('doesn', 4.4389241148208014e-11), ('did', 2.2465971912337144e-13), ('years', 0.0), ('drive', 0.0)]
# Topic 47:
# [('years', 6.6677636968235445), ('14', 1.2751864116335483e-05), ('10', 2.6956188695474806e-07), ('ll', 1.3903178498918772e-07), ('better', 6.650526353681285e-08), ('just', 6.143551397240817e-08), ('let', 3.612398247064999e-08), ('ve', 2.3535168616868568e-08), ('new', 1.9094305620304244e-08), ('doesn', 1.0450999245438461e-11)]
# Topic 48:
# [('program', 7.06180511292364), ('14', 1.8449745784859188e-05), ('file', 2.716716429447747e-06), ('just', 4.791601311019476e-07), ('let', 2.2308765299830326e-07), ('better', 7.07649522900037e-08), ('ll', 5.7684024084747145e-08), ('help', 3.4509715382265686e-08), ('10', 3.4268182450771054e-08), ('run', 2.4388248192818573e-08)]
# Topic 49:
# [('help', 6.763664281845987), ('file', 9.472791213928732e-07), ('thanks', 1.844517070841498e-07), ('data', 3.4027828234876873e-10), ('set', 1.4255590542598127e-10), ('mail', 1.0111244939824172e-10), ('doesn', 2.439191757452786e-12), ('really', 2.902175817466536e-16), ('g9v', 0.0), ('don', 0.0)]
# Topic 50:
# [('true', 8.41865955953694), ('file', 4.0575356235680685e-07), ('just', 4.905845704129855e-08), ('let', 3.126822259967296e-08), ('set', 4.021161919038478e-10), ('doesn', 1.6072582283806428e-11), ('line', 1.2161104025684224e-11), ('did', 8.271840889462728e-15), ('god', 0.0), ('don', 0.0)]
# Topic 51:
# [('power', 7.441517902530572), ('14', 3.365243865931654e-05), ('10', 7.18506528376973e-07), ('let', 1.2488574409449163e-07), ('better', 8.964424855551878e-08), ('just', 8.874011759642159e-08), ('ve', 2.958478380086828e-08), ('ll', 2.8973333959950798e-08), ('doesn', 6.436309886859814e-13), ('did', 1.2369231695991952e-14)]
# Topic 52:
# [('better', 9.09615026076978), ('a86', 0.0018379516363226716), ('g9v', 0.0004008895553174866), ('ve', 1.9869187323583005e-08), ('doesn', 4.9310149246513495e-11), ('did', 5.095804817825216e-13), ('going', 0.0), ('don', 0.0), ('drive', 0.0), ('edu', 0.0)]
# Topic 53:
# [('case', 8.480552715286777), ('ax', 1.3439374697903718e-05), ('power', 3.876995956551928e-08), ('better', 3.431504280321415e-08), ('let', 2.6743344082499282e-08), ('ve', 1.839789493463396e-08), ('doesn', 2.0188982284815194e-11), ('did', 4.0306266261800296e-13), ('years', 0.0), ('drive', 0.0)]
# Topic 54:
# [('software', 5.07318344305804), ('14', 2.4682826466242636e-05), ('know', 1.4785206419054614e-06), ('file', 1.4621936114137973e-07), ('new', 3.4152223472233536e-08), ('use', 1.7003447761560008e-08), ('ll', 1.623324919068533e-08), ('better', 1.3271364717351009e-08), ('data', 4.994533171671209e-10), ('line', 1.4610164204358807e-10)]
# Topic 55:
# [('information', 7.942254581703874), ('14', 3.914174723929667e-05), ('file', 1.7409209884255407e-06), ('10', 3.5307356905500177e-07), ('just', 1.650162687243197e-07), ('thanks', 2.8767543824931257e-08), ('25', 7.311629545057852e-09), ('edu', 1.9892118831600108e-09), ('data', 1.220737569230466e-09), ('mail', 1.7357604380161048e-10)]
# Topic 56:
# [('best', 8.204604070842944), ('better', 1.0177598056342472e-07), ('data', 5.8147239513274394e-11), ('doesn', 9.929933504293077e-12), ('did', 1.6301969395275513e-15), ('years', 0.0), ('drive', 0.0), ('edu', 0.0), ('fact', 0.0), ('far', 0.0)]
# Topic 57:
# [('number', 4.819947109509453), ('14', 7.403051339669781e-06), ('file', 7.955398376803114e-08), ('let', 5.50787160005844e-08), ('better', 4.060666089246758e-08), ('10', 3.728484345266385e-08), ('25', 4.449535424934612e-09), ('doesn', 4.022489044597469e-12), ('fact', 0.0), ('good', 0.0)]
# Topic 58:
# [('read', 5.203479232047101), ('ax', 6.78211041982699e-05), ('mr', 8.279547937534644e-07), ('file', 4.4902809421479555e-07), ('ll', 1.09900347864959e-07), ('just', 1.809195835992244e-08), ('let', 1.3504261809692182e-08), ('ve', 1.8703359855415626e-10), ('doesn', 1.2596270985032855e-11), ('did', 4.6672458215771877e-14)]
# Topic 59:
# [('doesn', 5.6306502916960115), ('ll', 1.0266654349772147e-07), ('better', 4.2681254713547376e-08), ('let', 2.0644013570976655e-09), ('data', 1.3133879739623051e-11), ('going', 0.0), ('don', 0.0), ('drive', 0.0), ('edu', 0.0), ('fact', 0.0)]
# Topic 60:
# [('didn', 5.892745629731335), ('tell', 2.5237583124587546e-07), ('let', 1.1279519073249535e-07), ('ll', 9.868974241147595e-08), ('file', 8.108388678391738e-08), ('better', 7.409966450219176e-08), ('just', 5.3647547947979935e-09), ('line', 5.731576901316374e-11), ('doesn', 7.066329771220021e-12), ('did', 1.0193826402395177e-12)]
# Topic 61:
# [('look', 6.76559492343372), ('file', 4.180225216903905e-07), ('let', 1.1250515707123028e-07), ('ll', 7.221623876544134e-08), ('better', 6.471591682068732e-08), ('25', 5.913698774478438e-09), ('did', 4.1454919614677136e-14), ('years', 0.0), ('good', 0.0), ('drive', 0.0)]
# Topic 62:
# [('list', 5.052174110679218), ('14', 5.186678362300817e-06), ('file', 1.1694508553443643e-06), ('10', 1.2443955259054998e-07), ('let', 1.034315670314995e-07), ('just', 5.9578428497964115e-08), ('better', 4.307733145246813e-08), ('ll', 3.2577406952575176e-08), ('thanks', 3.032793092083084e-08), ('new', 1.231196212546925e-08)]
# Topic 63:
# [('data', 6.595183931454236), ('ax', 0.0003265077537024111), ('14', 4.0840759624738086e-05), ('10', 1.65095278318088e-06), ('file', 1.5965974111494049e-06), ('just', 1.1702289382120496e-06), ('available', 6.540119463579306e-07), ('let', 3.3761532292903754e-07), ('better', 1.8412963282456644e-07), ('ve', 8.007883513070089e-08)]
# Topic 64:
# [('law', 8.650123685754336), ('14', 3.323080645893107e-05), ('government', 1.0386882673665448e-06), ('file', 4.766488455932163e-07), ('let', 7.163659809337217e-08), ('information', 3.1896642319329445e-08), ('just', 2.5625862133329907e-08), ('new', 1.5702035041529799e-09), ('data', 2.490676535032233e-10), ('doesn', 1.0065996141068668e-12)]
# Topic 65:
# [('let', 4.711312849572839), ('a86', 0.0016918138941182058), ('g9v', 0.00044725292460698026), ('know', 7.165936920944732e-05), ('government', 3.3361946558338066e-08), ('ll', 2.697935354978958e-08), ('doesn', 3.2535040007815044e-12), ('did', 8.740349781794337e-14), ('god', 0.0), ('don', 0.0)]
# Topic 66:
# [('world', 6.938146121241844), ('just', 1.4043571568504922e-07), ('let', 1.1471760968784313e-07), ('government', 1.0870846991583609e-07), ('new', 5.685053226001914e-08), ('better', 4.18819487041957e-08), ('ve', 1.6637813863549186e-08), ('ll', 8.369772726085968e-09), ('doesn', 2.9069518421677516e-12), ('did', 1.4832921509961572e-13)]
# Topic 67:
# [('government', 5.761285594388283), ('people', 0.0012166336139196555), ('make', 1.5034263796888283e-06), ('mr', 1.755869643028634e-07), ('new', 1.520750543954306e-07), ('let', 1.4563860285492966e-07), ('like', 8.292488129866321e-08), ('state', 5.238048604108757e-08), ('ll', 4.026048137360342e-08), ('years', 1.3812053043410755e-08)]
# Topic 68:
# [('lot', 4.5284984696534565), ('people', 5.869259394122271e-06), ('ll', 4.910911411653758e-08), ('let', 2.988081197798016e-08), ('better', 2.3864462077907208e-08), ('ve', 6.599278017381862e-09), ('did', 4.5424122980815344e-14), ('really', 1.1648863180546812e-15), ('don', 0.0), ('drive', 0.0)]
# Topic 69:
# [('00', 5.28863041289078), ('14', 1.2629483954094929e-05), ('20', 2.173167559389061e-08), ('15', 8.93838650605561e-10), ('did', 4.24000462933196e-14), ('got', 0.0), ('drive', 0.0), ('edu', 0.0), ('fact', 0.0), ('far', 0.0)]
# Topic 70:
# [('long', 4.805001044204947), ('14', 1.863108206047685e-06), ('just', 2.075677869448701e-07), ('new', 1.601122139556385e-07), ('better', 6.104776222468358e-08), ('ll', 2.146255088683708e-08), ('ve', 2.039644699412212e-08), ('really', 6.253868197502404e-15), ('drive', 0.0), ('going', 0.0)]
# Topic 71:
# [('try', 4.500476656203804), ('file', 6.644370497026964e-07), ('problem', 5.550773230295191e-07), ('just', 1.6053099378245343e-07), ('let', 6.477823861600363e-08), ('ll', 4.354029163135314e-08), ('better', 3.686467076435876e-08), ('ve', 1.8794778912491702e-08), ('doesn', 1.255073631976804e-11), ('information', 0.0)]
# Topic 72:
# [('course', 4.4409924763762465), ('new', 4.993401632609446e-08), ('let', 3.943917298713533e-08), ('data', 2.1212882521571387e-11), ('years', 0.0), ('going', 0.0), ('don', 0.0), ('drive', 0.0), ('edu', 0.0), ('fact', 0.0)]
# Topic 73:
# [('things', 5.26280238487457), ('like', 5.679149781307298e-07), ('let', 7.749541382547592e-08), ('better', 7.279182960370834e-08), ('new', 5.6538059657041646e-08), ('thing', 2.6706789608842364e-08), ('going', 2.6026998379451217e-08), ('ll', 1.0652979608376318e-08), ('ve', 4.949698965055787e-09), ('data', 1.1927169130182095e-11)]
# Topic 74:
# [('available', 4.522046535688804), ('a86', 0.0010357576049352965), ('g9v', 0.00031980224163181015), ('know', 6.3725464000536605e-06), ('thanks', 4.087456277911623e-08), ('government', 1.490398572852356e-08), ('data', 4.6464260462667424e-10), ('mail', 7.915765779678286e-11), ('line', 7.200019746439402e-11), ('really', 1.1633769438537094e-14)]
# Topic 75:
# [('set', 4.7132129091585195), ('ax', 0.00020415572446502955), ('14', 2.1908995128537866e-05), ('file', 6.442311020385405e-07), ('just', 1.9979764518964642e-07), ('let', 3.9629072047449754e-08), ('better', 2.968399267173547e-08), ('ve', 4.180733850637805e-09), ('use', 1.3984339651336826e-09), ('don', 0.0)]
# Topic 76:
# [('day', 3.1281962126336196), ('14', 3.408348290470215e-07), ('just', 4.509252703439716e-08), ('let', 3.313130866616988e-08), ('10', 1.4093827157320579e-08), ('new', 1.3969404026681902e-08), ('jesus', 8.200771728947156e-09), ('ll', 7.458221229075444e-09), ('doesn', 1.6049333762793742e-12), ('did', 9.698230192852e-14)]
# Topic 77:
# [('thing', 4.549096461382594), ('like', 1.1250725994690587e-06), ('tell', 3.9719367850250095e-07), ('better', 8.132083326002979e-08), ('let', 3.199182746510708e-08), ('little', 1.66619736834729e-08), ('doesn', 1.1168598423076358e-12), ('did', 6.37319621749063e-14), ('25', 0.0), ('got', 0.0)]
# Topic 78:
# [('line', 3.9383768872859926), ('ax', 0.00012726338408957117), ('14', 1.835170520444303e-05), ('file', 7.903557361650293e-07), ('10', 5.447928536770709e-07), ('just', 5.438006664135366e-07), ('let', 1.918697395046252e-07), ('better', 5.887847699853733e-08), ('ll', 5.711909718987129e-08), ('ve', 2.1216082125511392e-08)]
# Topic 79:
# [('run', 3.618205776212003), ('problem', 1.9031209823536097e-06), ('does', 1.0807141006520752e-06), ('just', 3.860933929194739e-07), ('file', 3.258725232212434e-07), ('let', 8.47068752204998e-08), ('ll', 7.393547414760287e-08), ('better', 5.244265454096171e-08), ('10', 4.3654004372262e-08), ('thanks', 2.4827136767646496e-08)]
# Topic 80:
# [('little', 3.2615606718097667), ('ll', 3.5670571554723275e-08), ('come', 7.8792114452869e-09), ('ve', 5.737489802036328e-09), ('let', 3.165088480882208e-09), ('didn', 1.0479083755726793e-09), ('thanks', 6.387848481969928e-10), ('max', 4.905988756905039e-10), ('going', 4.22683141160871e-10), ('data', 1.2323207390167988e-11)]
# Topic 81:
# [('state', 3.3004205283998624), ('14', 9.861543496356236e-06), ('people', 6.7019836902029096e-06), ('fact', 8.795223452492368e-08), ('mr', 7.18509583641486e-08), ('file', 6.93710835822388e-08), ('10', 2.6719072307252006e-08), ('ll', 1.8506441944449944e-08), ('come', 1.0042724979938886e-08), ('new', 6.6046894830382005e-09)]
# Topic 82:
# [('second', 2.9064855138725827), ('14', 6.380734255794743e-06), ('people', 2.937310017231224e-06), ('10', 1.6900901281532357e-07), ('let', 8.255352688824917e-08), ('better', 2.5371971560872903e-08), ('ll', 2.214571685575084e-08), ('come', 1.516774315002911e-08), ('just', 1.472633122020589e-08), ('going', 5.500657221105954e-09)]
# Topic 83:
# [('fact', 3.207059863112153), ('people', 5.568412857934204e-06), ('14', 1.316993196005281e-06), ('tell', 6.792653277166421e-07), ('mr', 7.847885315966175e-08), ('like', 7.052214660578981e-08), ('let', 5.7743948294807376e-08), ('come', 2.8809375513207006e-08), ('better', 1.996271392190018e-08), ('new', 1.6143298115101256e-08)]
# Topic 84:
# [('different', 3.177334165909718), ('ax', 2.7362662614806184e-05), ('problem', 1.4912478780606438e-06), ('tell', 3.5588771031277427e-07), ('come', 3.0635158543829656e-08), ('like', 2.854488929059038e-08), ('better', 1.542181379055741e-08), ('things', 8.20993475719305e-09), ('thanks', 4.805525682844983e-09), ('going', 3.1746411105751733e-09)]
# Topic 85:
# [('come', 3.7689079715455893), ('14', 8.915706932106714e-06), ('just', 2.7372554639786365e-07), ('let', 7.790350143085686e-08), ('jesus', 7.316875728873014e-08), ('ll', 6.162322717479119e-08), ('better', 3.843891546430651e-08), ('going', 3.07160927951335e-08), ('things', 2.8378480548227873e-08), ('new', 2.8299806200542227e-08)]
# Topic 86:
# [('far', 3.075800927642246), ('know', 5.968507875772522e-05), ('people', 4.729668130205888e-06), ('14', 2.2974985149814594e-07), ('let', 7.596806749365232e-08), ('better', 3.8438681544095933e-08), ('just', 3.7134444189555064e-08), ('jesus', 1.5220991184200352e-08), ('going', 1.4130323863795136e-08), ('things', 9.402945977705627e-09)]
# Topic 87:
# [('jesus', 2.8595325573611694), ('time', 0.00024414310955261074), ('people', 0.00013498624392690805), ('know', 0.00010148179758345696), ('does', 2.202354940876884e-05), ('make', 2.0867409035967493e-05), ('point', 1.9261299531704104e-05), ('14', 1.7598577596424343e-05), ('god', 7.024575174732863e-06), ('believe', 6.297270601932857e-06)]
# Topic 88:
# [('12', 2.7744419311214177), ('14', 0.0001423221032795922), ('10', 3.5186799991070843e-06), ('just', 5.697849957239713e-07), ('mr', 1.7892682708549427e-07), ('25', 1.7142181028761415e-07), ('better', 1.3766391604082275e-07), ('ll', 1.2189021442248042e-07), ('let', 1.0797494644116785e-07), ('new', 3.117593059829785e-08)]
# Topic 89:
# [('mr', 2.7498879307721364), ('b8f', 0.003101944168673389), ('g9v', 0.0006701002658575187), ('people', 3.445886555916068e-05), ('know', 1.654941636238245e-05), ('time', 4.800622359855039e-06), ('tell', 2.6551879355793193e-06), ('make', 5.353753214497217e-07), ('believe', 1.1334642120170447e-07), ('things', 6.991740023236668e-08)]
# Topic 90:
# [('20', 2.5371174208122773), ('14', 2.619112113292493e-05), ('10', 4.4412239600842347e-07), ('believe', 6.580902515937527e-08), ('years', 2.5508768767621384e-08), ('god', 2.502197482970384e-08), ('better', 1.8973138911748334e-08), ('come', 5.053943734342029e-09), ('25', 3.886671603360264e-09), ('said', 3.8508336042716524e-09)]
# Topic 91:
# [('15', 2.1965948765131085), ('14', 0.00011814992987806062), ('10', 2.2808937232380013e-06), ('just', 4.747269985402357e-07), ('file', 4.594714485389189e-07), ('ll', 4.000789479605027e-07), ('mr', 2.480014851797997e-07), ('25', 1.1234557185978006e-07), ('let', 1.1172839941767413e-07), ('better', 1.0428959804749642e-07)]
# Topic 92:
# [('16', 2.3107331121233794), ('14', 8.13092169288181e-05), ('ax', 4.585486712426952e-05), ('10', 1.5283224142855143e-06), ('mr', 7.820220581710114e-07), ('ll', 4.87091660087394e-07), ('just', 2.743320517399034e-07), ('25', 1.5156589209389125e-07), ('point', 1.2724139354234584e-07), ('file', 1.2401627200375148e-07)]
# Topic 93:
# [('25', 2.4565154164324006), ('b8f', 0.0001725322974696434), ('14', 1.0711160841646676e-05), ('god', 1.4402297942978061e-08), ('20', 6.749538013386054e-09), ('going', 3.760927959087572e-09), ('come', 3.2920995790318145e-09), ('drive', 3.1386334727600886e-09), ('years', 8.426391169878343e-10), ('new', 4.4223627716368545e-10)]
# Topic 94:
# [('14', 2.356512184685274), ('a86', 0.034141061939806), ('b8f', 0.018239082380018888), ('g9v', 0.011401324337731136), ('people', 1.0882598069883299e-05), ('12', 7.4567171885997216e-06), ('tell', 2.378402921099361e-07), ('say', 7.05051567689721e-08), ('like', 6.548509476767708e-08), ('things', 2.6560996791525933e-08)]
# Topic 95:
# [('max', 2.1028828385756184), ('ax', 0.00024284880509900766), ('14', 2.944135586108332e-05), ('mr', 2.6285550431052165e-06), ('know', 1.2664889000052097e-06), ('ll', 6.786408533435317e-07), ('problem', 4.928661976592204e-07), ('10', 3.759322656222019e-07), ('tell', 1.6606555752780887e-07), ('didn', 3.6570817532994296e-09)]
# Topic 96:
# [('ax', 1.8541280804742741), ('b8f', 0.13478639912442283), ('a86', 0.06896830067877759), ('g9v', 0.06146029875817172), ('max', 0.009113613072390185), ('25', 3.0021842026727287e-05), ('mr', 6.014058476594132e-06), ('20', 8.629813405674893e-09), ('long', 1.2809846551498934e-09), ('lot', 4.456443180378469e-10)]
# Topic 97:
# [('new', 2.5859279050896187), ('b8f', 0.0016882103811017395), ('time', 0.00026656343113035173), ('people', 4.562742695375279e-05), ('know', 3.2327344373176315e-05), ('does', 7.024728120227349e-06), ('make', 5.874856545023831e-06), ('tell', 3.1180809300725864e-06), ('problem', 1.4501835794403326e-06), ('point', 1.447084010924104e-06)]
# Topic 98:
# [('know', 3.901529242105233), ('time', 6.22444330554636e-05), ('people', 1.1248654012679741e-05), ('does', 3.5474257442206363e-06), ('tell', 2.1041989023091553e-06), ('make', 1.3776045903045465e-06), ('believe', 1.2620433217890505e-07), ('point', 1.1621696769259076e-07), ('say', 6.135750045556677e-08), ('thanks', 5.1905510273941114e-08)]
# Topic 99:
# [('new', 7.645726082306095), ('g9v', 2.96906556440667e-05), ('try', 1.1352057407317698e-08), ('look', 2.5166408298901768e-09), ('question', 1.0983937549256568e-09), ('list', 3.4467645619061495e-10), ('drive', 1.2779965595216236e-10), ('mail', 1.1814005864074078e-10), ('got', 4.6394379910700543e-11), ('key', 1.1494840917123997e-11)]

# %% [markdown]
# * display top 10 words from each topic from LDA model

# %%
print("LDA Model:")
print_topics(lda, count_vec)
# Out:
# LDA Model:
# Topic 0:
# [('people', 2076.0369855399726), ('god', 1961.0182740158004), ('government', 1167.3700394675188), ('law', 1036.1825508006202), ('believe', 965.0523957513936), ('does', 931.4622051041653), ('jesus', 887.0999468312318), ('state', 720.939754114056), ('question', 694.4593507322932), ('right', 663.0098920462898)]
# Topic 1:
# [('ax', 62387.099998807396), ('max', 4531.217620738386), ('g9v', 1166.0999981563643), ('b8f', 1111.0999957688675), ('a86', 916.0999960650672), ('14', 115.42083266659765), ('mr', 100.71429057192557), ('25', 49.94675397250037), ('ll', 8.95500425744777), ('12', 4.204068808161783)]
# Topic 2:
# [('edu', 2403.98081529731), ('com', 1375.4846686185003), ('mail', 937.2485830801152), ('list', 688.586686506407), ('available', 507.54609960953184), ('information', 337.5703252439141), ('use', 145.1295022407829), ('like', 143.5294515042493), ('thanks', 140.0768825923925), ('new', 136.75367239208163)]
# Topic 3:
# [('space', 1279.909893757134), ('data', 1044.2060773103772), ('power', 954.459349275239), ('information', 197.0391178712987), ('second', 189.20162768307793), ('program', 164.35476116104059), ('available', 150.47211726900687), ('time', 140.65496947125968), ('new', 118.68247911614174), ('10', 103.95428211718176)]
# Topic 4:
# [('10', 1439.6426574545078), ('00', 1201.7948946996378), ('15', 928.3243602408628), ('25', 898.206679257904), ('12', 845.9428381145681), ('20', 833.0140151229713), ('16', 789.4746193151292), ('14', 746.3469845988451), ('mr', 737.1282084806974), ('new', 225.12659699852122)]
# Topic 5:
# [('said', 1496.8036938867951), ('people', 1306.5533939177433), ('time', 1288.6458869223916), ('did', 1265.168113369611), ('know', 1046.5159160660676), ('didn', 939.5332678373659), ('going', 923.8803948619161), ('just', 702.7547842095713), ('got', 677.9296135530309), ('years', 670.2934226651851)]
# Topic 6:
# [('like', 2637.599579994604), ('don', 2613.834725213399), ('just', 2356.6482535574432), ('think', 1691.7461380030995), ('know', 1521.201934935754), ('ve', 1477.0597232040354), ('good', 1337.863044057543), ('want', 1165.7922464411895), ('make', 1048.471812073768), ('really', 1044.6730561849654)]
# Topic 7:
# [('new', 1413.7747594214386), ('drive', 1126.0999389210901), ('use', 994.0599116514877), ('year', 657.4069057578423), ('software', 519.3398211562215), ('number', 344.1731199810178), ('used', 338.5973206632202), ('available', 327.6462117152824), ('case', 280.0893393381774), ('years', 258.44300391973593)]
# Topic 8:
# [('bit', 1211.7400900114785), ('key', 1136.9070482427203), ('used', 698.0807230631436), ('using', 392.2826544874467), ('use', 312.7492438319254), ('number', 251.94004036572534), ('16', 201.47297489744267), ('data', 137.50200805465965), ('line', 125.70716554523396), ('time', 106.6530276682928)]
# Topic 9:
# [('file', 1738.099869791656), ('windows', 1236.6679101814264), ('program', 1216.9893733638035), ('information', 801.0381920854243), ('does', 727.7749812848034), ('thanks', 724.9073356129003), ('use', 718.1554487719702), ('help', 560.4189579695139), ('set', 533.0446958490714), ('using', 504.08347905061885)]

# %% [markdown]
# ### Stretch: Use LDA w/ Gensim to do the same thing.
