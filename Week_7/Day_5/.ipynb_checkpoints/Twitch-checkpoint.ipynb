# %%
import pandas as pd

df = pd.read_csv('Twitch_game_data.csv')

# %%
df
# Out:
#        Rank                              Game  Month  Year  Hours_watched  \
# 0         1                 League of Legends      1  2016       94377226
# 1         2  Counter-Strike: Global Offensive      1  2016       47832863
# 2         3                            Dota 2      1  2016       45185893
# 3         4                       Hearthstone      1  2016       39936159
# 4         5       Call of Duty: Black Ops III      1  2016       16153057
# ...     ...                               ...    ...   ...            ...
# 13395   196              Farming Simulator 19      7  2021         734652
# 13396   197                         RuneScape      7  2021         727039
# 13397   198                     Demon's Souls      7  2021         724001
# 13398   199             Football Manager 2021      7  2021         696341
# 13399   200            Dungeon Fighter Online      7  2021         689837
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# ...

# %%
df['Game'].nunique()
# Out:
# 1692

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)
# pd.set_option('display.max_colwidth', None)

pd.set_option('display.max_rows', 60)
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 80)
pd.set_option('display.max_colwidth', 50)

# %%
df['Game'].value_counts()
# Out:
# Dungeons & Dragons      68
# League of Legends       67
# osu!                    67
# Magic: The Gathering    67
# Music                   67
#                         ..
# Golf Story               1
# Hob                      1
# MU Legend                1
# Hidden Agenda            1
# Splitgate                1
# Name: Game, Length: 1692, dtype: int64

# %%
# Top three games on Twitch for each year

#df[(df['Rank'] <= 3) & (df['Month'] == 1)]
top_games = df.groupby(['Year','Game']).sum()['Hours_watched'].sort_values(ascending=False)
top_games_list = top_games.tolist()
top_games
# Out:
# Year  Game
# 2020  Just Chatting                       1995891029
# 2021  Just Chatting                       1827518216
# 2020  League of Legends                   1553536532
# 2018  Fortnite                            1358048914
# 2021  Grand Theft Auto V                  1202343310
#                                              ...
# 2016  Goat Simulator                           95776
#       Cards Against Humanity                   95184
#       Hitman: Blood Money                      93954
#       Savage: Resurrection                     93754
#       The Mean Greens: Plastic Warfare         92460
# Name: Hours_watched, Length: 3192, dtype: int64

# %%
top_games[top_games == 1995891029].index[0]
# Out:
# (2020, 'Just Chatting')

# %%
hours_watched_list = []
year_list = []
game_list = []
count = 0

for i in [2016, 2017, 2018, 2019, 2020, 2021]:
    for j in range(0, len(top_games_list)):
        if top_games[top_games == top_games_list[j]].index[0][0] == i:
            hours_watched_list.append(top_games_list[j])
            year_list.append(top_games[top_games == top_games_list[j]].index[0][0])
            game_list.append(top_games[top_games == top_games_list[j]].index[0][1])
            count += 1
        if count == 3:
            count = 0
            break

# %%
game_list
# Out:
# ['League of Legends',
#  'Counter-Strike: Global Offensive',
#  'Dota 2',
#  'League of Legends',
#  "PLAYERUNKNOWN'S BATTLEGROUNDS",
#  'Dota 2',
#  'Fortnite',
#  'League of Legends',
#  'Dota 2',
#  'League of Legends',
#  'Fortnite',
#  'Just Chatting',
#  'Just Chatting',
#  'League of Legends',
#  'Fortnite',
#  'Just Chatting',
#  'Grand Theft Auto V',
#  'League of Legends']

# %%
import plotly.express as px

fig = px.bar(x=year_list, y=hours_watched_list, color=game_list, 
             barmode='relative', width=1000, title = 'Most Popular Games by Year based on Avg Hours Watched')
fig.update_layout(autosize = False, title={'x':0.45}, font={'size':15}, yaxis_title = 'Average Hours Watched (Billions)', xaxis_title = 'Year', bargap=0)   # set title coordinates
fig.show()

# %%
df
# Out:
#        Rank                              Game  Month  Year  Hours_watched  \
# 0         1                 League of Legends      1  2016       94377226
# 1         2  Counter-Strike: Global Offensive      1  2016       47832863
# 2         3                            Dota 2      1  2016       45185893
# 3         4                       Hearthstone      1  2016       39936159
# 4         5       Call of Duty: Black Ops III      1  2016       16153057
# ...     ...                               ...    ...   ...            ...
# 13395   196              Farming Simulator 19      7  2021         734652
# 13396   197                         RuneScape      7  2021         727039
# 13397   198                     Demon's Souls      7  2021         724001
# 13398   199             Football Manager 2021      7  2021         696341
# 13399   200            Dungeon Fighter Online      7  2021         689837
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# ...

# %%
df.groupby(['Year', 'Month']).sum()['Avg_viewers'].reset_index()
# Out:
#     Year  Month  Avg_viewers
# 0   2016      1       593033
# 1   2016      2       597543
# 2   2016      3       625403
# 3   2016      4       613548
# 4   2016      5       574557
# ..   ...    ...          ...
# 62  2021      3      2662288
# 63  2021      4      2834516
# 64  2021      5      2858061
# 65  2021      6      2469007
# 66  2021      7      2373169
#
# [67 rows x 3 columns]

# %%
import itertools
sums = df.groupby(['Year', 'Month']).sum().reset_index()
sums['Date'] = pd.to_datetime([f'{y}-{m}-{d}' for y, m, d in zip(sums.Year, sums.Month, itertools.repeat(1))])
sums
# Out:
#     Year  Month   Rank  Hours_watched  Peak_viewers  Peak_channels  Streamers  \
# 0   2016      1  20100      440695158      13835909          38823    1690892
# 1   2016      2  20100      415361414       4738043          40582    1662437
# 2   2016      3  20100      464749316       6131211          41194    1724196
# 3   2016      4  20100      441211782       5859357          41864    1641525
# 4   2016      5  20100      426970292       5203928          46592    1831310
# ..   ...    ...    ...            ...           ...            ...        ...
# 62  2021      3  20100     1978145900      17115297         210222    6680929
# 63  2021      4  20100     2038084346      19973256         253616    6574253
# 64  2021      5  20100     2123620503      20730635         230731    6244818
# 65  2021      6  20100     1775287252      17978096         197000    5546550
# 66  2021      7  20100     1763341235      18165095         181556    5677298
#
# ...

# %%
import plotly.express as px

fig = px.line(sums, x="Date", y="Avg_viewers", width=1000, title = 'Sum of Average Viewers from 2016 - 2021', markers=True)
fig.update_layout(autosize = False, title={'x':0.45}, font={'size':15}, yaxis_title = 'Sum of Average Viewers', xaxis_title = 'Date')   # set title coordinates
fig.show()

# %%
import plotly.express as px

fig = px.line(sums, x="Date", y="Peak_viewers", width=1000, title = 'Sum of Peak Viewers from 2016 - 2021', markers=True)
fig.update_layout(autosize = False, title={'x':0.45}, font={'size':15}, yaxis_title = 'Sum of Peak Viewers', xaxis_title = 'Date')   # set title coordinates
fig.show()

# %% [markdown]
# # Game Sales Data

# %%
df2 = pd.read_csv('game_sales_data.csv', encoding = 'unicode_escape', engine ='python')

# %%
df2
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                   Counter-Strike: Global Offensive       PC
# 3          4                                     Mario Kart Wii      Wii
# 4          5                      PLAYERUNKNOWN'S BATTLEGROUNDS       PC
# ...      ...                                                ...      ...
# 19595  19594  FirePower for Microsoft Combat Flight Simulator 3       PC
# 19596  19595                         Tom Clancy's Splinter Cell       PC
# 19597  19596             Ashita no Joe 2: The Anime Super Remix      PS2
# 19598  19597               Tokyo Yamanote Boys for V: Main Disc      PSV
# 19599  19598             NadePro!! Kisama no Seiyuu Yatte Miro!      PS2
#
#               Publisher              Developer  Critic_Score  User_Score  \
# ...

# %%
df2.describe()
# Out:
#                Rank  Critic_Score   User_Score  Total_Shipped          Year
# count  19600.000000   9969.000000  2223.000000   19600.000000  19600.000000
# mean    9798.539133      7.034848     6.994872       0.551123   2007.789949
# std     5658.110539      1.558968     1.517038       1.671466      6.326169
# min        1.000000      0.800000     1.000000       0.010000   1977.000000
# 25%     4898.750000      6.100000     6.300000       0.050000   2004.000000
# 50%     9798.500000      7.300000     7.200000       0.160000   2008.000000
# 75%    14698.250000      8.200000     8.000000       0.460000   2012.000000
# max    19598.000000     10.000000    10.000000      82.900000   2020.000000

# %%
df2[df2['Name'] == "Tom Clancy's Splinter Cell"]
# Out:
#         Rank                        Name Platform Publisher Developer  \
# 575      574  Tom Clancy's Splinter Cell       XB   Ubisoft   Ubisoft
# 712      711  Tom Clancy's Splinter Cell      PS2   Ubisoft   Ubisoft
# 7956    7955  Tom Clancy's Splinter Cell       GC   Ubisoft   Ubisoft
# 12252  12251  Tom Clancy's Splinter Cell      GBA   Ubisoft   Ubisoft
# 19596  19595  Tom Clancy's Splinter Cell       PC   Ubisoft   Ubisoft
#
#        Critic_Score  User_Score  Total_Shipped  Year
# 575             9.3         9.1           3.02  2002
# 712             9.1         NaN           2.65  2003
# 7956            9.1         NaN           0.23  2003
# 12252           8.0         NaN           0.10  2003
# 19596           9.4         NaN           0.01  2003

# %%
df2.groupby('Name').sum()['Total_Shipped']["Tom Clancy's Splinter Cell"]
# Out:
# 6.01

# %%
df3 = df2.groupby('Name').sum()['Total_Shipped'].reset_index()
df3
# Out:
#                                Name  Total_Shipped
# 0                       '98 Koshien           0.41
# 1                  - Arcane Raise -           0.12
# 2           .hack//G.U. Last Recode           0.24
# 3        .hack//G.U. Vol.1//Rebirth           0.17
# 4      .hack//G.U. Vol.2//Reminisce           0.23
# ...                             ...            ...
# 13607            thinkSMART FAMILY!           0.03
# 13608            thinkSMART Kids 8+           0.01
# 13609    thinkSMART: Chess for Kids           0.01
# 13610                  uDraw Studio           2.44
# 13611  uDraw Studio: Instant Artist           0.19
#
# [13612 rows x 2 columns]

# %%
fig = px.box(df3, y="Total_Shipped", title = 'Box Plot of Aggregated Total Game Sales')
fig.update_layout(autosize = False, title={'x':0.5}, font={'size':15}, yaxis_title = 'Total Shipped (Millions)')#, xaxis_title = '')#, yaxis_range=[-1,5])
fig.show()

# %%
fig = px.box(df3, y="Total_Shipped", title = 'Box Plot of Aggregated Total Game Sales (Truncated at 5M)')
fig.update_layout(autosize = False, title={'x':0.5}, font={'size':15}, yaxis_title = 'Total Shipped (Millions)', xaxis_title = '', yaxis_range=[-0.5,5])
fig.show()

# %%
df3.describe()
# Out:
#        Total_Shipped
# count   13612.000000
# mean        0.793566
# std         2.412139
# min         0.010000
# 25%         0.060000
# 50%         0.180000
# 75%         0.590000
# max        82.900000

# %%
# League of Legends
# CSGO ---
# Dota 2
# PUBG ---
# Fortnite
# Just Chatting?
# GTAV ---

# %%
sales_list = []
sales_list.append(df2.groupby('Name').sum()['Total_Shipped']["Counter-Strike: Global Offensive"])
sales_list.append(df2.groupby('Name').sum()['Total_Shipped']["PLAYERUNKNOWN'S BATTLEGROUNDS"])
sales_list.append(df2.groupby('Name').sum()['Total_Shipped']["Grand Theft Auto V"])

name_list = ['Counter-Strike: Global Offensive', "PLAYERUNKNOWN'S BATTLEGROUNDS", 'Grand Theft Auto V']
name_list2 = ['CS:GO', "PUBG", 'GTAV']

# %%
fig = px.bar(x=name_list2, y=sales_list, 
             width=700, title = 'Total Game Sales for Top Twitch Games')#, barmode='relative')
fig.update_layout(autosize = False, title={'x':0.5}, font={'size':15}, yaxis_title = 'Total Shipped (Millions)', xaxis_title = 'Game Title')#, bargap=0)
fig.show()
